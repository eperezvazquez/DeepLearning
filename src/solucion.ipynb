# %%
# %pip install sklearn
# %pip install plotly
# %pip install pydot
# %pip install graphviz
# %pip install pandas
# %pip install numpy
# %pip install matploylib
# Out:
# Requirement already satisfied: sklearn in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (from sklearn) (1.1.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.23.1)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.9.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: plotly in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (from plotly) (8.0.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pydot in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (from pydot) (3.0.9)
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: graphviz in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (0.20.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (1.4.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.23.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (1.23.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matploylib (from versions: none)
# ERROR: No matching distribution found for matploylib
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
''' importamos las librerias''' 

import numpy as np
import sys
import tensorflow as tf
import os
import sys
import pandas as pd
import keras,os
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from keras.preprocessing.image import ImageDataGenerator

# %%
# mostrar imagenes de Gatos
# plot dog photos from the dogs vs cats dataset
from matplotlib import pyplot
from matplotlib.image import imread
# define location of dataset
folder = 'train/'
# plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# define filename
	filename = folder + 'dog.' + str(i) + '.jpg'
	# load image pixels
	image = imread(filename)
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
# plot cat photos from the dogs vs cats dataset
from matplotlib import pyplot
from matplotlib.image import imread
# define location of dataset
folder = 'train/'
# plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# define filename
	filename = folder + 'cat.' + str(i) + '.jpg'
	# load image pixels
	image = imread(filename)
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
#Use the ImageDataGenerator to load the data
trdata = ImageDataGenerator()
traindata = trdata.flow_from_directory(directory="../src/",target_size=(224,224))
tsdata = ImageDataGenerator()
testdata = tsdata.flow_from_directory(directory="../src/", target_size=(224,224))
# Out:
# Found 37500 images belonging to 2 classes.
# Found 37500 images belonging to 2 classes.

# %%
#Pass the data to the neural network
model = Sequential()
model.add(Conv2D(input_shape=(224,224,3),filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

# %%
#Pass the data to the dense layer
model.add(Flatten())
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=2, activation="sigmoid"))

# %%
#Compile the model
from keras.optimizers import Adam
opt = Adam(lr=0.001)
model.compile(optimizer=opt, loss=keras.losses.binary_crossentropy, metrics=['accuracy'])
# Out:
# c:\Users\perez\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# %pip install visualkeras
import visualkeras
visualkeras.layered_view(model, legend=True)
# Out:
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.15-cp310-cp310-win_amd64.whl (43 kB)
#      ---------------------------------------- 43.2/43.2 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.1 in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (from visualkeras) (1.23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\perez\appdata\local\programs\python\python310\lib\site-packages (from visualkeras) (9.2.0)
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.15 visualkeras-0.0.2
# Note: you may need to restart the kernel to use updated packages.
# <PIL.Image.Image image mode=RGBA size=2235x1231>

# %%
#Get the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 64)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 128)     73856
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 128)     147584
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 256)       590080
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 256)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 512)       1180160
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 512)      0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 4096)              102764544
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 2)                 8194
#
# =================================================================
# Total params: 134,268,738
# Trainable params: 134,268,738
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Create objects for ModelCheckpoint and EarlyStopping, and pass them as callback functions to fit_generator
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint("vgg16_1.h5", monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', save_freq=1)
early = EarlyStopping(monitor='val_acc', min_delta=0, patience=20, verbose=1, mode='auto')
hist=model.fit_generator(steps_per_epoch=5,
                         generator=traindata, 
                         validation_data= testdata, 
                         validation_steps=1,
                         epochs=5,
                         callbacks=[checkpoint,early])
# Out:
# C:\Users\perez\AppData\Local\Temp\ipykernel_17324\942113687.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist=model.fit_generator(steps_per_epoch=5,
# Epoch 1/5
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1/5 [=====>........................] - ETA: 1:13 - loss: 0.7315 - accuracy: 0.2812WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2/5 [===========>..................] - ETA: 49s - loss: 2309.5208 - accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 3/5 [=================>............] - ETA: 33s - loss: 1539.9215 - accuracy: 0.4688WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/5 [=======================>......] - ETA: 16s - loss: 1155.1211 - accuracy: 0.4375WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 5/5 [==============================] - ETA: 0s - loss: 924.2345 - accuracy: 0.4625  WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 5/5 [==============================] - 92s 19s/step - loss: 924.2345 - accuracy: 0.4625 - val_loss: 0.6679 - val_accuracy: 0.6250
# Epoch 2/5
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1/5 [=====>........................] - ETA: 1:05 - loss: 0.6401 - accuracy: 0.6875WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2/5 [===========>..................] - ETA: 49s - loss: 2.4938 - accuracy: 0.6562 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 3/5 [=================>............] - ETA: 32s - loss: 1.8847 - accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/5 [=======================>......] - ETA: 16s - loss: 1.5872 - accuracy: 0.6016WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 5/5 [==============================] - ETA: 0s - loss: 1.4081 - accuracy: 0.6000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 5/5 [==============================] - 89s 18s/step - loss: 1.4081 - accuracy: 0.6000 - val_loss: 0.6942 - val_accuracy: 0.4375
# Epoch 3/5
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1/5 [=====>........................] - ETA: 1:09 - loss: 0.6902 - accuracy: 0.6875WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2/5 [===========>..................] - ETA: 50s - loss: 0.6893 - accuracy: 0.7031 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 3/5 [=================>............] - ETA: 33s - loss: 0.6882 - accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/5 [=======================>......] - ETA: 16s - loss: 0.6867 - accuracy: 0.7344WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 5/5 [==============================] - ETA: 0s - loss: 0.6832 - accuracy: 0.7188 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 5/5 [==============================] - 88s 18s/step - loss: 0.6832 - accuracy: 0.7188 - val_loss: 0.4804 - val_accuracy: 0.8125
# Epoch 4/5
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1/5 [=====>........................] - ETA: 1:04 - loss: 0.9164 - accuracy: 0.5625WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2/5 [===========>..................] - ETA: 49s - loss: 0.8134 - accuracy: 0.4219 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 3/5 [=================>............] - ETA: 32s - loss: 0.7668 - accuracy: 0.5104WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/5 [=======================>......] - ETA: 16s - loss: 0.7378 - accuracy: 0.5703WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 5/5 [==============================] - ETA: 0s - loss: 0.7263 - accuracy: 0.5750 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 5/5 [==============================] - 86s 17s/step - loss: 0.7263 - accuracy: 0.5750 - val_loss: 0.6076 - val_accuracy: 0.7188
# Epoch 5/5
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1/5 [=====>........................] - ETA: 1:07 - loss: 0.5838 - accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 2/5 [===========>..................] - ETA: 49s - loss: 0.7180 - accuracy: 0.7031 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 3/5 [=================>............] - ETA: 32s - loss: 0.6929 - accuracy: 0.6979WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/5 [=======================>......] - ETA: 16s - loss: 0.6933 - accuracy: 0.6406WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 5/5 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.6062 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 5/5 [==============================] - 86s 17s/step - loss: 0.6933 - accuracy: 0.6062 - val_loss: 0.6932 - val_accuracy: 0.5312

# %%
#Visualise training/validation accuracy and loss
import matplotlib.pyplot as plt
plt.plot(hist.history["accuracy"])
plt.plot(hist.history['val_accuracy'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","Validation Accuracy","loss","Validation Loss"])
plt.show()

# %%
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
loss = hist.history['loss']
val_loss = hist.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'go', label='Training Loss')
plt.plot(epochs, val_loss, 'g', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
# Evaluacion del Modelo

test_loss, test_acc = model.evaluate(testdata, steps=len(testdata), verbose=1)
print('Loss: %.3f' % (test_loss * 100.0))
print('Accuracy: %.3f' % (test_acc * 100.0))
# Out:
# 1172/1172 [==============================] - 4602s 4s/step - loss: 0.6943 - accuracy: 0.4576
# Loss: 69.427
# Accuracy: 45.763

# %%
from sklearn.metrics import confusion_matrix
import itertools

# %%
predictions = model.predict(x=testdata, steps= len(testdata), verbose=0)

# %%
testdata.classes
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
cm = confusion_matrix(y_true=testdata.classes, y_pred=np.argmax(predictions, axis=-1))

# %%
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
        print(cm)
    
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
        horizontalalignment="center",
        color="white" if cm[i, j] > thresh else "black")
        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

# %%
cm_plot_labels = ['0_cat', '1_dog']

plot_confusion_matrix(cm=cm, classes=cm_plot_labels, title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[ 7930  4570]
#  [15873  9127]]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/perez/OneDrive/Desktop/ProjectoML/src/test1/1839.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
#Make predictions
import keras
import tensorflow as tf
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

#imgage = mpimg.imread('C:/Users/perez/OneDrive/Desktop/ProjectoML/src/test1/1839.jpg')
image = tf.keras.preprocessing.image.load_img('C:/Users/perez/OneDrive/Desktop/ProjectoML/src/test1/1839.jpg',target_size=(224,224))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = model.predict(input_arr)
img = np.asarray(img)
plt.imshow(img)
img = np.expand_dims(img, axis=0)
from keras.models import load_model
saved_model = load_model("vgg16_1.h5")
output = saved_model.predict(img)
if output[0][0] > output[0][1]:
    print("cat")
else:
    print('dog')
# Out:
# 1/1 [==============================] - 0s 225ms/step
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\perez\OneDrive\Desktop\ProjectoML\src\solucion.ipynb Cell 22 in <cell line: 17>()
#      <a href='vscode-notebook-cell:/c%3A/Users/perez/OneDrive/Desktop/ProjectoML/src/solucion.ipynb#X31sZmlsZQ%3D%3D?line=14'>15</a> img = np.expand_dims(img, axis=0)
#      <a href='vscode-notebook-cell:/c%3A/Users/perez/OneDrive/Desktop/ProjectoML/src/solucion.ipynb#X31sZmlsZQ%3D%3D?line=15'>16</a> from keras.models import load_model
# ---> <a href='vscode-notebook-cell:/c%3A/Users/perez/OneDrive/Desktop/ProjectoML/src/solucion.ipynb#X31sZmlsZQ%3D%3D?line=16'>17</a> saved_model = load_model("vgg16_1.h5")
#      <a href='vscode-notebook-cell:/c%3A/Users/perez/OneDrive/Desktop/ProjectoML/src/solucion.ipynb#X31sZmlsZQ%3D%3D?line=17'>18</a> output = saved_model.predict(img)
#      <a href='vscode-notebook-cell:/c%3A/Users/perez/OneDrive/Desktop/ProjectoML/src/solucion.ipynb#X31sZmlsZQ%3D%3D?line=18'>19</a> if output[0][0] > output[0][1]:
#
# File c:\Users\perez\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File c:\Users\perez\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\saving\save.py:206, in load_model(filepath, custom_objects, compile, options)
#     204 if isinstance(filepath_str, str):
#     205   if not tf.io.gfile.exists(filepath_str):
# --> 206     raise IOError(f'No file or directory found at {filepath_str}')
#     208   if tf.io.gfile.isdir(filepath_str):
#     209     return saved_model_load.load(filepath_str, compile, options)
#
# OSError: No file or directory found at vgg16_1.h5

# %% [markdown]
# I select a cat picture and predicte a cat.

# %% [markdown]
# Source:
#
# https://machinelearningmastery.com/how-to-develop-a-convolutional-neural-network-to-classify-photos-of-dogs-and-cats/
#
# https://data-flair.training/blogs/cats-dogs-classification-deep-learning-project-beginners/
#
# https://towardsdatascience.com/step-by-step-vgg16-implementation-in-keras-for-beginners-a833c686ae6cSource:
#
# https://machinelearningmastery.com/how-to-develop-a-convolutional-neural-network-to-classify-photos-of-dogs-and-cats/
#
# https://data-flair.training/blogs/cats-dogs-classification-deep-learning-project-beginners/
#
# https://towardsdatascience.com/step-by-step-vgg16-implementation-in-keras-for-beginners-a833c686ae6c
#
# https://github.com/4GeeksAcademy/image-classifier-project-tutorial/blob/main/solution_guide.ipynb
